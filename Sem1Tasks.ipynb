# %% [markdown]
# ## Урок 1. Из каких этапов состоит подготовка отчета

# %% [markdown]
# ### Задача 1
# **Скачайте Power BI Desktop - в качестве подтверждения присылайте скрин интерфейса**

# %% [markdown]
# ![Sem1Scr.jpg](Sem1Scr.jpg)

# %% [markdown]
# ### Задачи 2-6
# **Распишите подробнее свой путь в аналитике и ожидания от обучения:**

# %% [markdown]
# <table align="center">
#   <tr align="center">
#     <td>Вопрос</td>
#     <td>Ответ</td>
#   </tr>
#     <tr align="center">
#     <td>Есть ли у вас опыт в аналитике и сколько лет?</td>
#     <td>В настоящее время опыта в аналитике как такового нет, но есть желание понять что это такое</td>
#   </tr>
#   <tr align="center">
#     <td>В каком направлении анализа планируете развиваться: BI, бизнес, финансовый, маркетинговый, HR, системный, продуктовая? Возможно вы руководитель или владелец бизнеса, тогда распишите как поможет аналитика в ваших задачах.</td>
#     <td>В настоящее время в интернете появились массивы открытых данных, которые хотелось бы научиться обрабатывать. Например, очень немногие знают, что в Москве на домах стоят камеры и если что-то случится можно через участкового восстановить историю событий. Адреса этих камер выложены на портале открытых данных Москвы</td>
#   </tr>
#   <tr align="center">
#     <td>Какие основные навыки вы хотите освоить?</td>
#     <td>В ходе обучения хотелось бы понять принципы формирования запросов для обработки данных, а также научиться правильно визуализировать результаты</td>
#   </tr>
#   <tr align="center">
#     <td>Есть ли у вас уже опыт работы в какой-то BI-системе и если да, то какой?</td>
#     <td>Я только на обучении узнала что есть такие BI-системы))</td>
#   </tr>
# </table>
